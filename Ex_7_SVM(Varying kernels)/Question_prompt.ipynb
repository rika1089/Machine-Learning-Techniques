# %% [markdown]
# Hey i am assigneed to perform the SVM in my lab now
#
#
# Apply and analyse Support Vector Machine algorithm with different kernel functions and parameter values for a linearly separable and non-linearly separable classification Task.
#
# So give me proper aim,Objective and a Dataset ,Dataset description and procedure with steps . and code for each step along with some explantion or description of that steps.
# Make sure except code alll the other explanation you provide in markdown cell formant so that i can easi;y paste it in my ipynb markdown cell
# .Alos the steps need dat have proer dataser loading,preprocessing and some EDA and then the rest like splitting traininng ,validating , testign evaluation etc

# %% [markdown]
# 7.
#
# 8
#
# Apply and analyse Support Vector Machine algorithm with different kernel functions and parameter
# values for a linearly separable and non-linearly separable classification Task
# Demonstrate the use of Relevance Vector Machine and compare results with other techniques
# such as SVM for a multi class classification application

# %% [markdown]
# OK now i wnat the same code format for any real world availabole dataset unlike synthetuicone
